-- %% [markdown]
-- # [TrendyolDB]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [TrendyolDB]    Script Date: 4/21/2024 6:22:45 PM ******/
CREATE DATABASE [TrendyolDB]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'TrendyolDB', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\TrendyolDB.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'TrendyolDB_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\TrendyolDB_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [TrendyolDB] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [TrendyolDB].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [TrendyolDB] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [TrendyolDB] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [TrendyolDB] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [TrendyolDB] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [TrendyolDB] SET ARITHABORT OFF 
GO
ALTER DATABASE [TrendyolDB] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [TrendyolDB] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [TrendyolDB] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [TrendyolDB] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [TrendyolDB] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [TrendyolDB] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [TrendyolDB] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [TrendyolDB] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [TrendyolDB] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [TrendyolDB] SET  ENABLE_BROKER 
GO
ALTER DATABASE [TrendyolDB] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [TrendyolDB] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [TrendyolDB] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [TrendyolDB] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [TrendyolDB] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [TrendyolDB] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [TrendyolDB] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [TrendyolDB] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [TrendyolDB] SET  MULTI_USER 
GO
ALTER DATABASE [TrendyolDB] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [TrendyolDB] SET DB_CHAINING OFF 
GO
ALTER DATABASE [TrendyolDB] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [TrendyolDB] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [TrendyolDB] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [TrendyolDB] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [TrendyolDB] SET QUERY_STORE = ON
GO
ALTER DATABASE [TrendyolDB] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Categories]

-- %%
USE [TrendyolDB]
GO

-- %%
/****** Object:  Table [dbo].[Categories]    Script Date: 4/21/2024 6:22:45 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Categories](
	[CategoryID] [int] NOT NULL,
	[CategoryName] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[CategoryID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Customers]

-- %%
/****** Object:  Table [dbo].[Customers]    Script Date: 4/21/2024 6:22:46 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Customers](
	[CustomerID] [int] NOT NULL,
	[Name] [nvarchar](50) NOT NULL,
	[Email] [nvarchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[CustomerID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Employees]

-- %%
/****** Object:  Table [dbo].[Employees]    Script Date: 4/21/2024 6:22:46 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Employees](
	[EmployeeID] [int] NOT NULL,
	[Name] [nvarchar](50) NULL,
	[Position] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[EmployeeID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[OrderDetails]

-- %%
/****** Object:  Table [dbo].[OrderDetails]    Script Date: 4/21/2024 6:22:46 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[OrderDetails](
	[OrderDetailID] [int] NOT NULL,
	[OrderID] [int] NOT NULL,
	[ProductID] [int] NOT NULL,
	[Quantity] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[OrderDetailID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Orders]

-- %%
/****** Object:  Table [dbo].[Orders]    Script Date: 4/21/2024 6:22:46 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Orders](
	[OrderID] [int] NOT NULL,
	[CustomerID] [int] NULL,
	[OrderDate] [date] NULL,
PRIMARY KEY CLUSTERED 
(
	[OrderID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Payments]

-- %%
/****** Object:  Table [dbo].[Payments]    Script Date: 4/21/2024 6:22:46 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Payments](
	[PaymentID] [int] NOT NULL,
	[OrderID] [int] NULL,
	[Amount] [int] NULL,
	[PaymentDate] [date] NULL,
PRIMARY KEY CLUSTERED 
(
	[PaymentID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ProductCategories]

-- %%
/****** Object:  Table [dbo].[ProductCategories]    Script Date: 4/21/2024 6:22:46 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ProductCategories](
	[ProductCategoryID] [int] NOT NULL,
	[ProductID] [int] NULL,
	[CategoryID] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ProductCategoryID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Products]

-- %%
/****** Object:  Table [dbo].[Products]    Script Date: 4/21/2024 6:22:46 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Products](
	[ProductID] [int] NOT NULL,
	[Name] [nvarchar](50) NOT NULL,
	[Price] [float] NULL,
	[StockQuantity] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ProductID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Shipments]

-- %%
/****** Object:  Table [dbo].[Shipments]    Script Date: 4/21/2024 6:22:46 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Shipments](
	[ShipmentID] [int] NOT NULL,
	[OrderID] [int] NULL,
	[ShipDate] [date] NULL,
PRIMARY KEY CLUSTERED 
(
	[ShipmentID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Suppliers]

-- %%
/****** Object:  Table [dbo].[Suppliers]    Script Date: 4/21/2024 6:22:46 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Suppliers](
	[SupplierID] [int] NOT NULL,
	[Name] [nvarchar](50) NULL,
	[ContactName] [nvarchar](50) NULL,
	[ContactEmail] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[SupplierID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Categories]

-- %%
INSERT [dbo].[Categories] ([CategoryID], [CategoryName]) VALUES (3, N'Accessories')
INSERT [dbo].[Categories] ([CategoryID], [CategoryName]) VALUES (1, N'Clothing')
INSERT [dbo].[Categories] ([CategoryID], [CategoryName]) VALUES (2, N'Footwear')
GO

-- %% [markdown]
-- # [dbo].[Customers]

-- %%
INSERT [dbo].[Customers] ([CustomerID], [Name], [Email]) VALUES (1, N'John Doe', N'john@example.com')
INSERT [dbo].[Customers] ([CustomerID], [Name], [Email]) VALUES (2, N'Jane Smith', N'jane@example.com')
INSERT [dbo].[Customers] ([CustomerID], [Name], [Email]) VALUES (3, N'Alice Johnson', N'alice@example.com')
GO

-- %% [markdown]
-- # [dbo].[Employees]

-- %%
INSERT [dbo].[Employees] ([EmployeeID], [Name], [Position]) VALUES (1, N'Michael Johnson', N'Manager')
INSERT [dbo].[Employees] ([EmployeeID], [Name], [Position]) VALUES (2, N'Emily Brown', N'Sales Associate')
INSERT [dbo].[Employees] ([EmployeeID], [Name], [Position]) VALUES (3, N'David White', N'Warehouse Manager')
GO

-- %% [markdown]
-- # [dbo].[OrderDetails]

-- %%
INSERT [dbo].[OrderDetails] ([OrderDetailID], [OrderID], [ProductID], [Quantity]) VALUES (1, 1, 1, 2)
INSERT [dbo].[OrderDetails] ([OrderDetailID], [OrderID], [ProductID], [Quantity]) VALUES (2, 1, 2, 1)
INSERT [dbo].[OrderDetails] ([OrderDetailID], [OrderID], [ProductID], [Quantity]) VALUES (3, 2, 3, 3)
GO

-- %% [markdown]
-- # [dbo].[Orders]

-- %%
INSERT [dbo].[Orders] ([OrderID], [CustomerID], [OrderDate]) VALUES (1, 1, CAST(N'2024-04-19' AS Date))
INSERT [dbo].[Orders] ([OrderID], [CustomerID], [OrderDate]) VALUES (2, 2, CAST(N'2024-04-18' AS Date))
INSERT [dbo].[Orders] ([OrderID], [CustomerID], [OrderDate]) VALUES (3, 3, CAST(N'2024-04-17' AS Date))
GO

-- %% [markdown]
-- # [dbo].[Payments]

-- %%
INSERT [dbo].[Payments] ([PaymentID], [OrderID], [Amount], [PaymentDate]) VALUES (1, 1, 50, CAST(N'2024-04-19' AS Date))
INSERT [dbo].[Payments] ([PaymentID], [OrderID], [Amount], [PaymentDate]) VALUES (2, 2, 100, CAST(N'2024-04-20' AS Date))
INSERT [dbo].[Payments] ([PaymentID], [OrderID], [Amount], [PaymentDate]) VALUES (3, 3, 75, CAST(N'2024-04-18' AS Date))
GO

-- %% [markdown]
-- # [dbo].[ProductCategories]

-- %%
INSERT [dbo].[ProductCategories] ([ProductCategoryID], [ProductID], [CategoryID]) VALUES (1, 1, 1)
INSERT [dbo].[ProductCategories] ([ProductCategoryID], [ProductID], [CategoryID]) VALUES (2, 2, 1)
INSERT [dbo].[ProductCategories] ([ProductCategoryID], [ProductID], [CategoryID]) VALUES (3, 3, 2)
GO

-- %% [markdown]
-- # [dbo].[Products]

-- %%
INSERT [dbo].[Products] ([ProductID], [Name], [Price], [StockQuantity]) VALUES (1, N'T-Shirt', 15.99, 100)
INSERT [dbo].[Products] ([ProductID], [Name], [Price], [StockQuantity]) VALUES (2, N'Jeans', 29.99, 50)
INSERT [dbo].[Products] ([ProductID], [Name], [Price], [StockQuantity]) VALUES (3, N'Sneakers', 49.99, 30)
GO

-- %% [markdown]
-- # [dbo].[Shipments]

-- %%
INSERT [dbo].[Shipments] ([ShipmentID], [OrderID], [ShipDate]) VALUES (1, 1, CAST(N'2024-04-20' AS Date))
INSERT [dbo].[Shipments] ([ShipmentID], [OrderID], [ShipDate]) VALUES (2, 2, CAST(N'2024-04-19' AS Date))
INSERT [dbo].[Shipments] ([ShipmentID], [OrderID], [ShipDate]) VALUES (3, 3, CAST(N'2024-04-18' AS Date))
GO

-- %% [markdown]
-- # [dbo].[Suppliers]

-- %%
INSERT [dbo].[Suppliers] ([SupplierID], [Name], [ContactName], [ContactEmail]) VALUES (1, N'ABC Textiles', N'John Smith', N'john@abc.com')
INSERT [dbo].[Suppliers] ([SupplierID], [Name], [ContactName], [ContactEmail]) VALUES (2, N'XYZ Clothing', N'Emily Jones', N'emily@xyz.com')
INSERT [dbo].[Suppliers] ([SupplierID], [Name], [ContactName], [ContactEmail]) VALUES (3, N'123 Shoes', N'Alice Johnson', N'alice@123shoes.com')
GO

-- %% [markdown]
-- # [UQ__Categori__8517B2E0D91ED6F5]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [UQ__Categori__8517B2E0D91ED6F5]    Script Date: 4/21/2024 6:22:46 PM ******/
ALTER TABLE [dbo].[Categories] ADD UNIQUE NONCLUSTERED 
(
	[CategoryName] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [UQ__Customer__A9D105342011463B]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [UQ__Customer__A9D105342011463B]    Script Date: 4/21/2024 6:22:46 PM ******/
ALTER TABLE [dbo].[Customers] ADD UNIQUE NONCLUSTERED 
(
	[Email] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [UQ__OrderDet__B40CC6ECE7CEC8C4]

-- %%
/****** Object:  Index [UQ__OrderDet__B40CC6ECE7CEC8C4]    Script Date: 4/21/2024 6:22:46 PM ******/
ALTER TABLE [dbo].[OrderDetails] ADD UNIQUE NONCLUSTERED 
(
	[ProductID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [UQ__Payments__C3905BAEE2F067FE]

-- %%
/****** Object:  Index [UQ__Payments__C3905BAEE2F067FE]    Script Date: 4/21/2024 6:22:46 PM ******/
ALTER TABLE [dbo].[Payments] ADD UNIQUE NONCLUSTERED 
(
	[OrderID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [UQ__Products__6089BD09ABD2F881]

-- %%
/****** Object:  Index [UQ__Products__6089BD09ABD2F881]    Script Date: 4/21/2024 6:22:46 PM ******/
ALTER TABLE [dbo].[Products] ADD UNIQUE NONCLUSTERED 
(
	[Price] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [UQ__Shipment__C3905BAEAE2113A6]

-- %%
/****** Object:  Index [UQ__Shipment__C3905BAEAE2113A6]    Script Date: 4/21/2024 6:22:46 PM ******/
ALTER TABLE [dbo].[Shipments] ADD UNIQUE NONCLUSTERED 
(
	[OrderID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__OrderDeta__Order__534D60F1]

-- %%
ALTER TABLE [dbo].[OrderDetails]  WITH CHECK ADD FOREIGN KEY([OrderID])
REFERENCES [dbo].[Orders] ([OrderID])
GO

-- %% [markdown]
-- # [FK__OrderDeta__Produ__5441852A]

-- %%
ALTER TABLE [dbo].[OrderDetails]  WITH CHECK ADD FOREIGN KEY([ProductID])
REFERENCES [dbo].[Products] ([ProductID])
GO

-- %% [markdown]
-- # [FK__Payments__OrderI__66603565]

-- %%
ALTER TABLE [dbo].[Payments]  WITH CHECK ADD FOREIGN KEY([OrderID])
REFERENCES [dbo].[Orders] ([OrderID])
GO

-- %% [markdown]
-- # [FK__ProductCa__Categ__5AEE82B9]

-- %%
ALTER TABLE [dbo].[ProductCategories]  WITH CHECK ADD FOREIGN KEY([CategoryID])
REFERENCES [dbo].[Categories] ([CategoryID])
GO

-- %% [markdown]
-- # [FK__ProductCa__Produ__59FA5E80]

-- %%
ALTER TABLE [dbo].[ProductCategories]  WITH CHECK ADD FOREIGN KEY([ProductID])
REFERENCES [dbo].[Products] ([ProductID])
GO

-- %% [markdown]
-- # [FK__Shipments__Order__628FA481]

-- %%
ALTER TABLE [dbo].[Shipments]  WITH CHECK ADD FOREIGN KEY([OrderID])
REFERENCES [dbo].[Orders] ([OrderID])
GO

-- %% [markdown]
-- # [TrendyolDB]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [TrendyolDB] SET  READ_WRITE 
GO
